# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Loss Function比较

df1 = pd.read_csv('results/resnet50-bs16-ep40-lr0.001-Adam.csv')
df2 = pd.read_csv('results/resnet50-bs16-ep40-lr0.001-SGD.csv')
df3 = pd.read_csv('results/resnet18-bs16-ep40-Adam.csv')
df4 = pd.read_csv('results/resnet18-bs16-ep40-SGD.csv')

df1.T.iloc[1].plot(label= '1')
df2.T.iloc[1].plot(label= '2')
df3.T.iloc[1].plot(label= '3')
df4.T.iloc[1].plot(label= '4')
plt.legend()
plt.show()
